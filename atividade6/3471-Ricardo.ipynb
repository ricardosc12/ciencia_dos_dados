# %% [markdown]
# > Introdução à Ciência dos Dados \
# > Ciência da Computação – UFV/Florestal
#
#
# * **Nome:** %s
# * **Matrícula:**  %d
#
# # Aula Prática 06
# ## Visualização de Dados
#
# **Objetivo:** Entender comandos para explorar dados visualmente por meio de gráficos.
# **Pré-requisitos:** Linguagem de programação Python, estatística básica \
# **Meta:** Ao final da prática, o aluno será capaz de analisar um conjunto de dados visualmente para ajudar na tomada de decisões.
#
# ----

# %%
### NÃO REMOVA ESSA CÉLULA! ####
# !pip --no-cache-dir install --upgrade learntools_dados_ufv

# !wget https://raw.githubusercontent.com/gfviegas/CCF425-resources/master/p6/OnlineRetail.xlsx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: learntools_dados_ufv in /usr/local/lib/python3.10/dist-packages (1.0.10)
# --2023-05-10 21:27:37--  https://raw.githubusercontent.com/gfviegas/CCF425-resources/master/p6/OnlineRetail.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23715344 (23M) [application/octet-stream]
# Saving to: ‘OnlineRetail.xlsx.1’
#
# OnlineRetail.xlsx.1 100%[===================>]  22.62M   146MB/s    in 0.2s
#
# 2023-05-10 21:27:38 (146 MB/s) - ‘OnlineRetail.xlsx.1’ saved [23715344/23715344]

# %%
#### Não altere essa célula!!! ####
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Roteiro

# %% [markdown]
# ## Leitura dos dados
# Veja os dados do arquivo `OnlineRetail.xlsx`.
#
# Note que o arquivo é um Excel. A biblioteca consegue ler e o interpretar da mesma maneira que um CSV, como estamos acostumados.
#
# Note que a função usada é a `read_excel` e não a `read_csv`.
#
# É normal que demore um pouco, pois os arquivos em excel possuem muito mais recursos e dados armazenados do que um simples csv.

# %%
df = pd.read_excel('./OnlineRetail.xlsx')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### Filtrar quantidades e preços unitários negativos

# %%
df = df[(df['Quantity'] > 0) & (df['UnitPrice'] > 0)]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [530104 rows x 8 columns]

# %% [markdown]
# ## Visualizar os dados
#
# ### Gráfico de Pontos (_Scatter Plot_)

# %%
df.plot(kind='scatter', x='UnitPrice', y='Quantity', color='orange', label='Transação')
# Adiciona um rótulo no eixo Y
plt.ylabel('Quantidade')
# Adiciona um rótulo no eixo X
plt.xlabel('Preço Unitário')

plt.show()

# %% [markdown]
# ### Usar escala logarítmica nos dois eixos para melhorar a visualização
# Também vamos gerar um gráfico colorindo e marcando por país

# %%
countries_colors = {
    'Brazil': '#FAA916',
    'USA': '#0FA3B1',
    'Canada': '#BB4430'
}

fig, ax = plt.subplots()
countries_data = list(map(lambda k: (k, df[df['Country'] == k]), countries_colors.keys()))
[ax.scatter(x=d['UnitPrice'], y=d['Quantity'], c=countries_colors[k], label=k) for (k, d) in countries_data]

plt.ylabel('Quantidade')
plt.xlabel('Preço Unitário')
plt.xscale('log')
plt.yscale('log')
ax.legend() # Habilita a legenda das cores
plt.show()

# %% [markdown]
# ### Usar um terceiro atributo para definir o tamanho do marcador
#
# Veja o argumento `s` (de size) da função scatter

# %%
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

fig, ax = plt.subplots()
countries_data = list(map(lambda k: (k, df[df['Country'] == k]), countries_colors.keys()))
[ax.scatter(x=d['UnitPrice'], y=d['Quantity'], c=countries_colors[k], s=d['TotalPrice'], label=k) for (k, d) in countries_data]

plt.ylabel('Quantidade')
plt.xlabel('Preço Unitário')
plt.xscale('log')
plt.yscale('log')
ax.legend() # Habilita a legenda das cores
plt.show()
# Out:
# <ipython-input-318-cf32b30b1a23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %% [markdown]
# ### Agrupar antes de exibir os gráficos
# Agrupando pelo `InvoiceNo`

# %%
group_invoice = df.groupby('InvoiceNo')

group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')
plt.xlabel('Quantidade')
plt.ylabel('Preço Total')
plt.show()
# Out:
# <ipython-input-319-f3633d45bd45>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')

# %% [markdown]
# ### Gerar o mesmo gráfico anterior na escala logarítmica

# %%
group_invoice = df.groupby('InvoiceNo')

group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')
plt.xlabel('Quantidade')
plt.ylabel('Preço Total')
plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# <ipython-input-320-7aabca3b295a>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')

# %% [markdown]
# ### Plotar gráfico de linha para avaliar tendência.
# Agrupar as compras por data e mostrar a quantidade de itens por data da compra.

# %%
group_date = df.groupby('InvoiceDate')
group_date.sum()['Quantity'].plot(c='#EF2D56')
plt.xlabel('Data Compra')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-321-bad57c7f8abe>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_date.sum()['Quantity'].plot(c='#EF2D56')

# %% [markdown]
# ### Agrupar por Mês/Ano

# %%
df['MonthYear'] = df['InvoiceDate'].dt.strftime('%m/%Y')

group_month_year = df.groupby('MonthYear')
group_month_year.sum()['Quantity'].plot(c='#EF2D56')
plt.xlabel('Data Compra')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-322-8c63bec423d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MonthYear'] = df['InvoiceDate'].dt.strftime('%m/%Y')
# <ipython-input-322-8c63bec423d7>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_month_year.sum()['Quantity'].plot(c='#EF2D56')

# %% [markdown]
# ### Plotar gráfico de barras para mostrar valores para atributos categóricos

# %%
group_invoice.sum().iloc[0:9]['Quantity'].plot(kind='bar', color='#EF2D56')
plt.xlabel('Número da NF')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-323-1911c4500e22>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().iloc[0:9]['Quantity'].plot(kind='bar', color='#EF2D56')

# %% [markdown]
# ### Plotar Histograma

# %%
group_invoice.sum()['TotalPrice'].plot(kind='hist', color='#EF2D56')
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-324-b381511109ff>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum()['TotalPrice'].plot(kind='hist', color='#EF2D56')

# %% [markdown]
# ### Filtrar para visualizar melhor a maioria
# O gráfico acima possui uma concentração em valores menores mas possui alguns outliers com preço **muito** superior à maioria. Vamos resolver isso com um filtro.

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56')
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-325-3249a7471aec>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56')
# <ipython-input-325-3249a7471aec>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56')

# %% [markdown]
# ### Alterar número de bins para ter mais detalhes

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56', bins=100)
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-326-a464e8af570c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56', bins=100)
# <ipython-input-326-a464e8af570c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56', bins=100)

# %% [markdown]
# ### Plotar um BoxPlot

# %%
group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço')
plt.show()
# Out:
# <ipython-input-327-dc603a4e5ac3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')

# %% [markdown]
# ### Usar escala logarítmica para ver melhor

# %%
group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço')
plt.yscale('log')
plt.show()
# Out:
# <ipython-input-328-d25ec2495cb5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')

# %% [markdown]
# ### Filtrar para valores menores

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço Total')
plt.show()
# Out:
# <ipython-input-329-ca2c8393e02a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot.box(color='#EF2D56')
# <ipython-input-329-ca2c8393e02a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot.box(color='#EF2D56')

# %% [markdown]
# ### Plotar boxplots agrupados por país

# %%
df.boxplot('TotalPrice', by='Country', rot=90, figsize=(15, 5), color='purple')
plt.ylabel('Preço Total')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Exercícios

# %% [markdown]
# Execute e não remova a célula abaixo antes de iniciar os exercícios. Faça todas as atividades manipulando a variável `df`.

# %%
# Atribui o dataframe com o estado "original" em uma variável isolada
original_df = pd.read_excel('./OnlineRetail.xlsx')
df = original_df
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## 1. Faça um gráfico de barras mostrando a quantidade total vendida de cada um dos 10 primeiros produtos que aparecem no Dataframe.
# Essa lista não possui correção automática.

# %%
# Resposta da 1.

produtos = df['Description'].unique()[0:10]
df_produtos = df[df['Description'].isin(produtos)]
group_date = df_produtos.groupby('Description')
group_date.sum()['Quantity'].plot.bar()
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-332-c39c0ee07d91>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_date.sum()['Quantity'].plot.bar()

# %% [markdown]
# ## 2. Faça um Boxplot dos preços unitários dos produtos. Considere somente os 10 produtos mais vendidos.
# Essa lista não possui correção automática.

# %%
total_price = df.groupby('Description').sum(numeric_only=True)
best_seller = total_price['Quantity'].sort_values(ascending=False)
best_seller = best_seller[0:10].index.tolist()
df_best_seller = df[df['Description'].isin(best_seller)]
df_best_seller.boxplot('UnitPrice', by='Description', rot=90)
# Out:
# <Axes: title={'center': 'UnitPrice'}, xlabel='Description'>

# %% [markdown]
# ## 3. Faça um gráfico de linhas mostrando o faturamento (total de preços das vendas) por dia.
# Essa lista não possui correção automática.

# %% [markdown]
# ### 1. Removido os valores negativos do total da venda
# ### 2. Adicionado a coluna TotalPrice ao DataFrame

# %%
df['TotalPrice'] = df['UnitPrice']*df['Quantity']

# %% [markdown]
# #### Agrupando os dias

# %%
df_positive = df[df['TotalPrice'] > 0]
group_day = df_positive.groupby(df['InvoiceDate'].dt.day)
group_day.sum()['TotalPrice'].plot()
plt.xlabel('Dia da Compra')
plt.ylabel('Total da verda')
plt.show()
# Out:
# <ipython-input-335-1e0963286765>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_day.sum()['TotalPrice'].plot()

# %% [markdown]
# ## 4. Faça o histograma da média dos preços unitários dos produtos.
# Essa lista não possui correção automática.

# %% [markdown]
# #### 1. Filtrado valores negativos

# %% [markdown]
# #### 2. Há alguns outliers em nossa amostra que inviabiliza a visualização do histograma. Com o describe podemos resumir os valores unitários e estabelecer um range para o histograma

# %%
df_positive = df[(df['UnitPrice'] >= 0)]
group_product = df_positive.groupby('Description')
print(df['UnitPrice'].describe())
group_product.mean()['UnitPrice'].plot.hist(rot=90, range=[0,5])
# plt.xscale('log')
# Out:
# count    541909.000000
# mean          4.611114
# std          96.759853
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64
# <ipython-input-362-3cbc495108b1>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_product.mean()['UnitPrice'].plot.hist(rot=90, range=[0,5])
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## 5. Faça dois gráficos de barras, sendo um da quantidade de compras e outro do total de faturamento por país.
# Essa lista não possui correção automática.

# %%
df_ = df[df['Quantity']>0]
group_by_country = df_.groupby('Country')
fig, (ax1, ax2) = plt.subplots(1, 2)
group_by_country.sum()['Quantity'].plot.bar(rot=90, ax=ax1, figsize=(20,5), color="#e085c2", title="Quantidade de compras totais por país")
group_by_country.sum()['TotalPrice'].plot.bar(rot=90, ax=ax2, figsize=(20,5), title="Faturament total por país")
ax1.set_yscale('log')
ax2.set_yscale('log')
# Out:
# <ipython-input-363-634593b37e72>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_by_country.sum()['Quantity'].plot.bar(rot=90, ax=ax1, figsize=(20,5), color="#e085c2", title="Quantidade de compras totais por país")
# <ipython-input-363-634593b37e72>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_by_country.sum()['TotalPrice'].plot.bar(rot=90, ax=ax2, figsize=(20,5), title="Faturament total por país")

# %% [markdown]
# ## 6. Considerando os 100 produtos mais vendidos, é possível visualizar alguma diferença entre a distribuição dos preços unitários desses produtos ao se comparar os países “Australia” e “United Kingdom”? Faça um ou mais gráficos para ajudar a responder.
# Essa lista não possui correção automática.

# %%
total_price = df.groupby('Description').sum(numeric_only=True)
best_seller = total_price['Quantity'].sort_values(ascending=False)
best_seller = best_seller[0:100].index.tolist()
df_best_seller = df[df['Description'].isin(best_seller)]
df_australia = df_best_seller[df_best_seller['Country'] == "Australia"]
df_united = df_best_seller[df_best_seller['Country'] == "United Kingdom"]

fig, (ax1, ax2) = plt.subplots(1, 2)

df_australia.groupby('Description').mean()['UnitPrice'].plot.bar(rot=90, ax=ax1, figsize=(20,5), title="Australia")
df_united.groupby('Description').mean()['UnitPrice'].plot.bar(rot=90, ax=ax2, figsize=(20,5), title="United Kingdom")
# Out:
# <ipython-input-364-220a1f5e4fd2>:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_australia.groupby('Description').mean()['UnitPrice'].plot.bar(rot=90, ax=ax1, figsize=(20,5), title="Australia")
# <ipython-input-364-220a1f5e4fd2>:11: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_united.groupby('Description').mean()['UnitPrice'].plot.bar(rot=90, ax=ax2, figsize=(20,5), title="United Kingdom")
# <Axes: title={'center': 'United Kingdom'}, xlabel='Description'>

# %% [markdown]
# ### Resposta
# ##### Com o gráfico podemos visualizar as médias dos preços unitários de cada produto vendido nos países. Nem todos os produtos mais vendidos estão em ambos os países.
# ##### No geral, United Kingdom tem suas médias de preços unitários mais alta que a Austrália. Como exemplo os produtos:
#
# ###### 1. JUMO BAG RED RETROSPOT
# ###### 2. PACK OF 60 PINK PASLEY CAKE CASES
# ###### 3. RABBIT NIGHT LIGHT

# %% [markdown]
# ## 7. Faça um gráfico de barras, de linhas, histograma e boxplot usando a biblioteca `seaborn`.
# Essa lista não possui correção automática.
#
# A biblioteca já está importada pelo nome de `sns`. Vai um gráfico de exemplo abaixo ;)

# %%
country_group_sum = df.groupby('Country').sum().reset_index()
plt.figure(figsize=(10,10))

# g=sns.barplot(data=country_group_sum, y='Country', x='Quantity', orient='h')
# g.set_xscale('log')

# plt.show()
# Out:
# <ipython-input-339-59a03b0d2f84>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   country_group_sum = df.groupby('Country').sum().reset_index()

# %%
g=sns.barplot(data=country_group_sum, y='Country', x='Quantity', orient='h')
g.set_xscale('log')

plt.show()

# %%
g=sns.lineplot(data=country_group_sum, y='Quantity', x='Country', orient='x')
g.set_yscale('log')
plt.xticks(rotation=90)
plt.show()

# %%
g=sns.histplot(data=country_group_sum, y='Quantity', x='Country')
g.set_yscale('log')
plt.xticks(rotation=90)
plt.show()

# %%
g=sns.boxplot(data=country_group_sum, y='Quantity', x='Country', orient='v')
g.set_yscale('log')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 7. Faça uma breve análise e comparação dos plots feitos com o `seaborn` e com o `matplotlib`.
# Qual você gostou mais? Viu alguma diferença em performance neles?

# %% [markdown]
# Resposta da 7:
#
# Tanto a Matplotlib quanto o Seaborn parecem semelhantes em termos de código e documentação quanto a funcionalidades, mas diferem em sixtaxe.
#
# Eu prefiro a Matplotlib, é uma escolha mais conveniente, já que possui uma interface integrada com o Pandas, tornando mais fácil a plotagem de gráficos diretamente a partir da manipulação de DataFrames. Além disso, a documentação do Pandas já vem descrita com o uso da biblioteca Matplotlib.
